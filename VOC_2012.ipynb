# %%
pip install pycocotools-windows
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pycocotools-windows (from versions: none)
# ERROR: No matching distribution found for pycocotools-windows
#
# [notice] A new release of pip is available: 24.0 -> 25.0
# [notice] To update, run: C:\Users\HP\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import os
import xml.etree.ElementTree as ET  # not used in this example since we use COCO API
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model
from pycocotools.coco import COCO

# %%
IMG_HEIGHT, IMG_WIDTH = 224, 224      # Input image dimensions
BATCH_SIZE = 16
EPOCHS = 10

# Dataset paths (adjust these as needed)
DATASET_DIR = 'C:/xampp/htdocs/AI-ML_Kit/Datasets/VOC_Yolo'
TRAIN_DIR = os.path.join(DATASET_DIR, 'C:/xampp/htdocs/AI-ML_Kit/Datasets/VOC_Yolo/train')   # (Not used in this demo)
VALID_DIR = os.path.join(DATASET_DIR, 'C:/xampp/htdocs/AI-ML_Kit/Datasets/VOC_Yolo/valid')
ANNOT_FILE = os.path.join(VALID_DIR, 'C:/xampp/htdocs/AI-ML_Kit/Datasets/VOC_Yolo/valid/_annotations.coco.json')

# %%
# Initialize COCO for the validation dataset
# ========================
# Note: We assume the COCO annotations file is in VALID_DIR
coco = COCO(ANNOT_FILE)
# Get all image IDs from the COCO annotations
img_ids = coco.getImgIds()

# Build a category mapping to contiguous labels
cats = coco.loadCats(coco.getCatIds())
# Sort category IDs to ensure consistency
sorted_cat_ids = sorted([cat['id'] for cat in cats])
cat_id_to_idx = {cat_id: idx for idx, cat_id in enumerate(sorted_cat_ids)}
NUM_CLASSES = len(sorted_cat_ids)
print("Found {} categories.".format(NUM_CLASSES))
# Out:
# loading annotations into memory...
# Done (t=0.13s)
# creating index...
# index created!
# Found 21 categories.

# %%
# Data Generator using COCO API
# ========================
def load_data_generator():
    """
    A generator that yields (image, (label, bbox)) tuples.
    For simplicity, for each image we use only the first annotation found.
    The bounding box is normalized to the range [0, 1] based on original image size.
    """
    for img_id in img_ids:
        img_info = coco.loadImgs(img_id)[0]
        file_name = img_info['file_name']
        img_path = os.path.join(VALID_DIR, file_name)
        
        # Read and preprocess the image
        img_raw = tf.io.read_file(img_path)
        img = tf.image.decode_jpeg(img_raw, channels=3)
        # Save original dimensions for bbox normalization
        orig_w, orig_h = img_info['width'], img_info['height']
        img = tf.image.resize(img, (IMG_HEIGHT, IMG_WIDTH))
        img = img / 255.0  # Normalize pixel values to [0,1]
        
        # Load annotations for this image
        ann_ids = coco.getAnnIds(imgIds=img_id)
        anns = coco.loadAnns(ann_ids)
        if len(anns) == 0:
            continue  # skip images with no annotations
        
        # Use the first annotation only for this demo
        ann = anns[0]
        # COCO bounding box format is [x, y, width, height]
        bbox = ann['bbox']
        xmin, ymin, box_width, box_height = bbox
        xmax = xmin + box_width
        ymax = ymin + box_height
        # Normalize bbox coordinates relative to original image dimensions
        xmin_norm = xmin / orig_w
        ymin_norm = ymin / orig_h
        xmax_norm = xmax / orig_w
        ymax_norm = ymax / orig_h
        bbox_norm = [xmin_norm, ymin_norm, xmax_norm, ymax_norm]
        
        # Convert category_id to contiguous label index
        cat_id = ann['category_id']
        label = cat_id_to_idx.get(cat_id, -1)
        if label == -1:
            continue
        
        yield img, (np.int32(label), np.array(bbox_norm, dtype=np.float32))

# Define the output signature for the generator
output_signature = (
    tf.TensorSpec(shape=(IMG_HEIGHT, IMG_WIDTH, 3), dtype=tf.float32),
    (tf.TensorSpec(shape=(), dtype=tf.int32),
     tf.TensorSpec(shape=(4,), dtype=tf.float32))
)

# %%
dataset = tf.data.Dataset.from_generator(load_data_generator, output_signature=output_signature)
dataset = dataset.shuffle(1000)
dataset = dataset.batch(BATCH_SIZE)
dataset = dataset.prefetch(tf.data.AUTOTUNE)

# %%
# For demonstration, split dataset into training and validation sets (80/20)
total_samples = sum(1 for _ in dataset.unbatch())
train_count = int(0.8 * total_samples)
val_count = total_samples - train_count

# Unbatch and then split
dataset = dataset.unbatch()
dataset = dataset.shuffle(total_samples)
train_dataset = dataset.take(train_count).batch(BATCH_SIZE)
val_dataset = dataset.skip(train_count).batch(BATCH_SIZE)

print("Total samples: {}, Training: {}, Validation: {}".format(total_samples, train_count, val_count))
# Out:
# Total samples: 3302, Training: 2641, Validation: 661

# %%
base_model = MobileNetV2(input_shape=(IMG_HEIGHT, IMG_WIDTH, 3),
                           include_top=False,
                           weights='imagenet')
base_model.trainable = False

# Global pooling layer
x = GlobalAveragePooling2D()(base_model.output)
# Classification head: outputs probabilities for NUM_CLASSES categories
class_output = Dense(NUM_CLASSES, activation='softmax', name='class_output')(x)
# Bounding box regression head: outputs 4 values (normalized bbox coordinates)
# Use sigmoid to ensure output is in [0,1]
bbox_output = Dense(4, activation='sigmoid', name='bbox_output')(x)

model = Model(inputs=base_model.input, outputs=[class_output, bbox_output])
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1 (Conv2D)      │ (None, 112, 112,  │        864 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_Conv1            │ (None, 112, 112,  │        128 │ Conv1[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1_relu (ReLU)   │ (None, 112, 112,  │          0 │ bn_Conv1[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │        288 │ Conv1_relu[0][0]  │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │        128 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │          0 │ expanded_conv_de… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 112, 112,  │        512 │ expanded_conv_de… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 112, 112,  │         64 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand      │ (None, 112, 112,  │      1,536 │ expanded_conv_pr… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_BN   │ (None, 112, 112,  │        384 │ block_1_expand[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_relu │ (None, 112, 112,  │          0 │ block_1_expand_B… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_pad         │ (None, 113, 113,  │          0 │ block_1_expand_r… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise   │ (None, 56, 56,    │        864 │ block_1_pad[0][0] │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 56, 56,    │        384 │ block_1_depthwis… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 56, 56,    │          0 │ block_1_depthwis… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project     │ (None, 56, 56,    │      2,304 │ block_1_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project_BN  │ (None, 56, 56,    │         96 │ block_1_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand      │ (None, 56, 56,    │      3,456 │ block_1_project_… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_BN   │ (None, 56, 56,    │        576 │ block_2_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_relu │ (None, 56, 56,    │          0 │ block_2_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise   │ (None, 56, 56,    │      1,296 │ block_2_expand_r… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 56, 56,    │        576 │ block_2_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 56, 56,    │          0 │ block_2_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project     │ (None, 56, 56,    │      3,456 │ block_2_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project_BN  │ (None, 56, 56,    │         96 │ block_2_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_add (Add)   │ (None, 56, 56,    │          0 │ block_1_project_… │
# │                     │ 24)               │            │ block_2_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand      │ (None, 56, 56,    │      3,456 │ block_2_add[0][0] │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_BN   │ (None, 56, 56,    │        576 │ block_3_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_relu │ (None, 56, 56,    │          0 │ block_3_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_pad         │ (None, 57, 57,    │          0 │ block_3_expand_r… │
# │ (ZeroPadding2D)     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise   │ (None, 28, 28,    │      1,296 │ block_3_pad[0][0] │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 28, 28,    │        576 │ block_3_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 28, 28,    │          0 │ block_3_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project     │ (None, 28, 28,    │      4,608 │ block_3_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project_BN  │ (None, 28, 28,    │        128 │ block_3_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand      │ (None, 28, 28,    │      6,144 │ block_3_project_… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_BN   │ (None, 28, 28,    │        768 │ block_4_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_relu │ (None, 28, 28,    │          0 │ block_4_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise   │ (None, 28, 28,    │      1,728 │ block_4_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 28, 28,    │        768 │ block_4_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 28, 28,    │          0 │ block_4_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project     │ (None, 28, 28,    │      6,144 │ block_4_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project_BN  │ (None, 28, 28,    │        128 │ block_4_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_add (Add)   │ (None, 28, 28,    │          0 │ block_3_project_… │
# │                     │ 32)               │            │ block_4_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand      │ (None, 28, 28,    │      6,144 │ block_4_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_BN   │ (None, 28, 28,    │        768 │ block_5_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_relu │ (None, 28, 28,    │          0 │ block_5_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise   │ (None, 28, 28,    │      1,728 │ block_5_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 28, 28,    │        768 │ block_5_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 28, 28,    │          0 │ block_5_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project     │ (None, 28, 28,    │      6,144 │ block_5_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project_BN  │ (None, 28, 28,    │        128 │ block_5_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_add (Add)   │ (None, 28, 28,    │          0 │ block_4_add[0][0… │
# │                     │ 32)               │            │ block_5_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand      │ (None, 28, 28,    │      6,144 │ block_5_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_BN   │ (None, 28, 28,    │        768 │ block_6_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_relu │ (None, 28, 28,    │          0 │ block_6_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_pad         │ (None, 29, 29,    │          0 │ block_6_expand_r… │
# │ (ZeroPadding2D)     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise   │ (None, 14, 14,    │      1,728 │ block_6_pad[0][0] │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 14, 14,    │        768 │ block_6_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 14, 14,    │          0 │ block_6_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project     │ (None, 14, 14,    │     12,288 │ block_6_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project_BN  │ (None, 14, 14,    │        256 │ block_6_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand      │ (None, 14, 14,    │     24,576 │ block_6_project_… │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_BN   │ (None, 14, 14,    │      1,536 │ block_7_expand[0… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_relu │ (None, 14, 14,    │          0 │ block_7_expand_B… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise   │ (None, 14, 14,    │      3,456 │ block_7_expand_r… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 14, 14,    │      1,536 │ block_7_depthwis… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 14, 14,    │          0 │ block_7_depthwis… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project     │ (None, 14, 14,    │     24,576 │ block_7_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project_BN  │ (None, 14, 14,    │        256 │ block_7_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_add (Add)   │ (None, 14, 14,    │          0 │ block_6_project_… │
# │                     │ 64)               │            │ block_7_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand      │ (None, 14, 14,    │     24,576 │ block_7_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_BN   │ (None, 14, 14,    │      1,536 │ block_8_expand[0… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_relu │ (None, 14, 14,    │          0 │ block_8_expand_B… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise   │ (None, 14, 14,    │      3,456 │ block_8_expand_r… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 14, 14,    │      1,536 │ block_8_depthwis… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 14, 14,    │          0 │ block_8_depthwis… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project     │ (None, 14, 14,    │     24,576 │ block_8_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project_BN  │ (None, 14, 14,    │        256 │ block_8_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_add (Add)   │ (None, 14, 14,    │          0 │ block_7_add[0][0… │
# │                     │ 64)               │            │ block_8_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand      │ (None, 14, 14,    │     24,576 │ block_8_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_BN   │ (None, 14, 14,    │      1,536 │ block_9_expand[0… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_relu │ (None, 14, 14,    │          0 │ block_9_expand_B… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise   │ (None, 14, 14,    │      3,456 │ block_9_expand_r… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 14, 14,    │      1,536 │ block_9_depthwis… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 14, 14,    │          0 │ block_9_depthwis… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project     │ (None, 14, 14,    │     24,576 │ block_9_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project_BN  │ (None, 14, 14,    │        256 │ block_9_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_add (Add)   │ (None, 14, 14,    │          0 │ block_8_add[0][0… │
# │                     │ 64)               │            │ block_9_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand     │ (None, 14, 14,    │     24,576 │ block_9_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_BN  │ (None, 14, 14,    │      1,536 │ block_10_expand[… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_re… │ (None, 14, 14,    │          0 │ block_10_expand_… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise  │ (None, 14, 14,    │      3,456 │ block_10_expand_… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 14, 14,    │      1,536 │ block_10_depthwi… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 14, 14,    │          0 │ block_10_depthwi… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project    │ (None, 14, 14,    │     36,864 │ block_10_depthwi… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project_BN │ (None, 14, 14,    │        384 │ block_10_project… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand     │ (None, 14, 14,    │     55,296 │ block_10_project… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_BN  │ (None, 14, 14,    │      2,304 │ block_11_expand[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_re… │ (None, 14, 14,    │          0 │ block_11_expand_… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise  │ (None, 14, 14,    │      5,184 │ block_11_expand_… │
# │ (DepthwiseConv2D)   │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 14, 14,    │      2,304 │ block_11_depthwi… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 14, 14,    │          0 │ block_11_depthwi… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project    │ (None, 14, 14,    │     55,296 │ block_11_depthwi… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project_BN │ (None, 14, 14,    │        384 │ block_11_project… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_add (Add)  │ (None, 14, 14,    │          0 │ block_10_project… │
# │                     │ 96)               │            │ block_11_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand     │ (None, 14, 14,    │     55,296 │ block_11_add[0][… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_BN  │ (None, 14, 14,    │      2,304 │ block_12_expand[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_re… │ (None, 14, 14,    │          0 │ block_12_expand_… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise  │ (None, 14, 14,    │      5,184 │ block_12_expand_… │
# │ (DepthwiseConv2D)   │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 14, 14,    │      2,304 │ block_12_depthwi… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 14, 14,    │          0 │ block_12_depthwi… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project    │ (None, 14, 14,    │     55,296 │ block_12_depthwi… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project_BN │ (None, 14, 14,    │        384 │ block_12_project… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_add (Add)  │ (None, 14, 14,    │          0 │ block_11_add[0][… │
# │                     │ 96)               │            │ block_12_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand     │ (None, 14, 14,    │     55,296 │ block_12_add[0][… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_BN  │ (None, 14, 14,    │      2,304 │ block_13_expand[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_re… │ (None, 14, 14,    │          0 │ block_13_expand_… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_pad        │ (None, 15, 15,    │          0 │ block_13_expand_… │
# │ (ZeroPadding2D)     │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise  │ (None, 7, 7, 576) │      5,184 │ block_13_pad[0][… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 7, 7, 576) │      2,304 │ block_13_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 7, 7, 576) │          0 │ block_13_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project    │ (None, 7, 7, 160) │     92,160 │ block_13_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project_BN │ (None, 7, 7, 160) │        640 │ block_13_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand     │ (None, 7, 7, 960) │    153,600 │ block_13_project… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_BN  │ (None, 7, 7, 960) │      3,840 │ block_14_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_re… │ (None, 7, 7, 960) │          0 │ block_14_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise  │ (None, 7, 7, 960) │      8,640 │ block_14_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 7, 7, 960) │      3,840 │ block_14_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 7, 7, 960) │          0 │ block_14_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project    │ (None, 7, 7, 160) │    153,600 │ block_14_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project_BN │ (None, 7, 7, 160) │        640 │ block_14_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_add (Add)  │ (None, 7, 7, 160) │          0 │ block_13_project… │
# │                     │                   │            │ block_14_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand     │ (None, 7, 7, 960) │    153,600 │ block_14_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_BN  │ (None, 7, 7, 960) │      3,840 │ block_15_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_re… │ (None, 7, 7, 960) │          0 │ block_15_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise  │ (None, 7, 7, 960) │      8,640 │ block_15_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 7, 7, 960) │      3,840 │ block_15_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 7, 7, 960) │          0 │ block_15_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project    │ (None, 7, 7, 160) │    153,600 │ block_15_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project_BN │ (None, 7, 7, 160) │        640 │ block_15_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_add (Add)  │ (None, 7, 7, 160) │          0 │ block_14_add[0][… │
# │                     │                   │            │ block_15_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand     │ (None, 7, 7, 960) │    153,600 │ block_15_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_BN  │ (None, 7, 7, 960) │      3,840 │ block_16_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_re… │ (None, 7, 7, 960) │          0 │ block_16_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise  │ (None, 7, 7, 960) │      8,640 │ block_16_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 7, 7, 960) │      3,840 │ block_16_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 7, 7, 960) │          0 │ block_16_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project    │ (None, 7, 7, 320) │    307,200 │ block_16_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project_BN │ (None, 7, 7, 320) │      1,280 │ block_16_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1 (Conv2D)     │ (None, 7, 7,      │    409,600 │ block_16_project… │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1_bn           │ (None, 7, 7,      │      5,120 │ Conv_1[0][0]      │
# │ (BatchNormalizatio… │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_relu (ReLU)     │ (None, 7, 7,      │          0 │ Conv_1_bn[0][0]   │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ out_relu[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ class_output        │ (None, 21)        │     26,901 │ global_average_p… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bbox_output (Dense) │ (None, 4)         │      5,124 │ global_average_p… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,290,009 (8.74 MB)
#  Trainable params: 32,025 (125.10 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
model.compile(optimizer='adam',
              loss={'class_output': 'sparse_categorical_crossentropy',
                    'bbox_output': 'mse'},
              metrics={'class_output': 'accuracy',
                       'bbox_output': 'mae'})

# ========================
# Train the Model
# ========================
history = model.fit(train_dataset,
                    validation_data=val_dataset,
                    epochs=EPOCHS)
# Out:
# Epoch 1/10
#     166/Unknown 111s 415ms/step - bbox_output_loss: 0.0756 - bbox_output_mae: 0.2096 - class_output_accuracy: 0.4936 - class_output_loss: 1.8935 - loss: 1.9691
# C:\Users\HP\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 161s 718ms/step - bbox_output_loss: 0.0755 - bbox_output_mae: 0.2094 - class_output_accuracy: 0.4943 - class_output_loss: 1.8905 - loss: 1.9661 - val_bbox_output_loss: 0.0431 - val_bbox_output_mae: 0.1601 - val_class_output_accuracy: 0.7443 - val_class_output_loss: 0.8525 - val_loss: 0.9266
# Epoch 2/10
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 110s 526ms/step - bbox_output_loss: 0.0415 - bbox_output_mae: 0.1569 - class_output_accuracy: 0.7535 - class_output_loss: 0.8207 - loss: 0.8622 - val_bbox_output_loss: 0.0352 - val_bbox_output_mae: 0.1463 - val_class_output_accuracy: 0.7882 - val_class_output_loss: 0.6282 - val_loss: 0.6805
# Epoch 3/10
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 104s 530ms/step - bbox_output_loss: 0.0379 - bbox_output_mae: 0.1495 - class_output_accuracy: 0.8097 - class_output_loss: 0.6479 - loss: 0.6859 - val_bbox_output_loss: 0.0315 - val_bbox_output_mae: 0.1385 - val_class_output_accuracy: 0.8260 - val_class_output_loss: 0.5346 - val_loss: 0.5740
# Epoch 4/10
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 100s 508ms/step - bbox_output_loss: 0.0329 - bbox_output_mae: 0.1390 - class_output_accuracy: 0.8110 - class_output_loss: 0.5981 - loss: 0.6310 - val_bbox_output_loss: 0.0313 - val_bbox_output_mae: 0.1323 - val_class_output_accuracy: 0.8638 - val_class_output_loss: 0.4459 - val_loss: 0.4891
# Epoch 5/10
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 105s 539ms/step - bbox_output_loss: 0.0328 - bbox_output_mae: 0.1386 - class_output_accuracy: 0.8495 - class_output_loss: 0.4688 - loss: 0.5016 - val_bbox_output_loss: 0.0309 - val_bbox_output_mae: 0.1334 - val_class_output_accuracy: 0.8835 - val_class_output_loss: 0.4047 - val_loss: 0.4375
# Epoch 6/10
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 102s 518ms/step - bbox_output_loss: 0.0312 - bbox_output_mae: 0.1346 - class_output_accuracy: 0.8799 - class_output_loss: 0.3917 - loss: 0.4229 - val_bbox_output_loss: 0.0295 - val_bbox_output_mae: 0.1355 - val_class_output_accuracy: 0.8896 - val_class_output_loss: 0.3259 - val_loss: 0.3610
# Epoch 7/10
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 100s 510ms/step - bbox_output_loss: 0.0303 - bbox_output_mae: 0.1339 - class_output_accuracy: 0.8947 - class_output_loss: 0.3329 - loss: 0.3632 - val_bbox_output_loss: 0.0287 - val_bbox_output_mae: 0.1329 - val_class_output_accuracy: 0.9395 - val_class_output_loss: 0.2490 - val_loss: 0.2860
# Epoch 8/10
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 101s 513ms/step - bbox_output_loss: 0.0290 - bbox_output_mae: 0.1302 - class_output_accuracy: 0.9086 - class_output_loss: 0.3036 - loss: 0.3326 - val_bbox_output_loss: 0.0256 - val_bbox_output_mae: 0.1266 - val_class_output_accuracy: 0.9486 - val_class_output_loss: 0.2248 - val_loss: 0.2590
# Epoch 9/10
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 101s 517ms/step - bbox_output_loss: 0.0286 - bbox_output_mae: 0.1300 - class_output_accuracy: 0.9307 - class_output_loss: 0.2505 - loss: 0.2792 - val_bbox_output_loss: 0.0236 - val_bbox_output_mae: 0.1202 - val_class_output_accuracy: 0.9455 - val_class_output_loss: 0.2055 - val_loss: 0.2358
# Epoch 10/10
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 100s 511ms/step - bbox_output_loss: 0.0269 - bbox_output_mae: 0.1249 - class_output_accuracy: 0.9341 - class_output_loss: 0.2243 - loss: 0.2512 - val_bbox_output_loss: 0.0264 - val_bbox_output_mae: 0.1257 - val_class_output_accuracy: 0.9531 - val_class_output_loss: 0.1850 - val_loss: 0.2195

# %%
model.save('object_detection_model.h5')
print("Model saved as object_detection_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved as object_detection_model.h5

# %%
print("Converting model to TensorFlow Lite format...")
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]  # Enable optimizations such as quantization
tflite_model = converter.convert()
tflite_filename = "object_detection_model.tflite"
with open(tflite_filename, "wb") as f:
    f.write(tflite_model)
print(f"Model converted and saved as {tflite_filename}")
# Out:
# Converting model to TensorFlow Lite format...
# INFO:tensorflow:Assets written to: C:\Users\HP\AppData\Local\Temp\tmpfydvyfoc\assets
# INFO:tensorflow:Assets written to: C:\Users\HP\AppData\Local\Temp\tmpfydvyfoc\assets
# Saved artifact at 'C:\Users\HP\AppData\Local\Temp\tmpfydvyfoc'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   List[TensorSpec(shape=(None, 21), dtype=tf.float32, name=None), TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)]
# Captures:
#   2294779372240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294779373776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294779373584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294779372816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294779371664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294779373968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294779372624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294779372432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294779373200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294779374544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294779375504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294779375120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294779371856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294779376272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294779375888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294779378384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780117648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780117264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294779379152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294779379344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780118224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780119184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780118992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780117840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780117456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780120528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780121872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780122064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780121680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780120912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780122448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780123792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780123984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780123600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780122832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780124368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780125712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780125904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780125520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780124752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780125136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780127824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780128016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780127632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780120144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780126288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780129936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780130128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780129744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780127248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780130512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780131856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780132048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780131664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780130896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780132432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050863056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050863632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780129360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2294780132816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050863440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050864976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050865168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050864784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050864016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050865552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050866896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050867088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050866704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050865936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050867472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050868816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050869008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050868624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050867856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050869392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050870736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050870928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050870544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050869776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050871312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050872656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050872848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050872464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050871696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050873232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050874576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050874768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050874384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050873616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050875152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050876496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050876688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050876304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050875536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050877072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050878416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050877840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050878224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050877456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295050878608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051486608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051486800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051486416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051485264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051487184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051488528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051488720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051488336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051487568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051489104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051490448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051490640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051490256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051489488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051491024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051492368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051492560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051492176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051491408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051492944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051494288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051494480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051494096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051493328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051494864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051496208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051496400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051496016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051495248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051496784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051498128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051498320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051497936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051497168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051498704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051500048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051500240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051499856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051499088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051500624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911710992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911711760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051486032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295051501008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911711568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911713104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911713296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911712912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911712144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911713680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911715024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911715216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911714832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911714064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911715600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911716944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911717136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911716752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911715984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911717520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911718864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911719056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911718672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911717904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911719440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911720784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911720976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911720592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911719824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911721360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911722704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911722896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911722512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911721744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911723280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911724624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911724816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911724432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911723664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911725200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911726544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911725968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911726352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911725584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295911726736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912121360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912120592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912121552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912120784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912122320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912123664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912123856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912123472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912122704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912124240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912125584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912125776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912125392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912124624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912126160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912127504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912127696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912127312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912126544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912128080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912129424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912129616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912129232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912128464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912130000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912131344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912131536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912131152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912130384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912131920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912133264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912133456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912133072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912132304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912133840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912135184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912135376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912134992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912134224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912135760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912464464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912465424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912121936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912136144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912465232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912466768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912466960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912466576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912465808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912467344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912468688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912468880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912468496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912467728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912469264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912470608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912470800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912470416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912469648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912471184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912472528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912472720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912472336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912471568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912473104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912474448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912474640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912474256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912473488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912475024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912476368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912476560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912476176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912475408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912478672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912479824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912477328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2295912479056: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Model converted and saved as object_detection_model.tflite
